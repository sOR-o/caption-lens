# %%
# !pip install einops -qq
# !pip install tensorflow_datasets -qq
# !pip install tensorflow-text -qq

# %%
import tensorflow as tf
import tensorflow_text as tf_text
import tensorflow_datasets as tfds

import numpy as np
import matplotlib.pyplot as plt
import os
import pathlib
import collections
import time
import string
import re
import einops
from tqdm.auto import tqdm
from PIL import Image
import nltk
from nltk.util import ngrams
import zipfile

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.get_logger().setLevel('ERROR')

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /Users/saurabh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/saurabh/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
def get_data(path='./dataset/flickr8k'):
    """
    Downloads and extracts the Flickr8k dataset and text files.
    
    Parameters:
        path (str): Path where the dataset will be stored.
    """
    path = pathlib.Path(path)
    dataset_path = path / 'Flicker8k_Dataset'  # Directory created after dataset extraction

    # Check if dataset and text files are already extracted
    if not dataset_path.exists():
        # Download and extract the Flickr8k Dataset
        tf.keras.utils.get_file(
            origin='https://github.com/jbrownlee/Datasets/releases/download/Flickr8k/Flickr8k_Dataset.zip',
            cache_dir='.',
            cache_subdir=path,
            extract=True
        )
        
        # Download and extract the Flickr8k text files
        tf.keras.utils.get_file(
            origin='https://github.com/jbrownlee/Datasets/releases/download/Flickr8k/Flickr8k_text.zip',
            cache_dir='.',
            cache_subdir=path,
            extract=True
        )


def get_dataset(path='./dataset/flickr8k'):
    """
    Reads and processes the Flickr8k dataset to create training and testing datasets.

    Parameters:
        path (str): Path where the dataset is stored.

    Returns:
        tuple: A tuple of training and testing datasets.
    """
    path = pathlib.Path(path)
    
    # Read and process captions
    captions = (path / 'Flickr8k.token.txt').read_text().splitlines()
    captions = [cap.split('\t') for cap in captions]
    captions = [(img_path.split('#')[0], cap) for (img_path, cap) in captions]
    
    # Create a dictionary of image paths and their respective captions
    cap_dict = collections.defaultdict(list)
    for img_path, cap in captions:
        cap_dict[img_path].append(cap)
    
    # Read training and testing image paths
    train_imgs_path = (path / 'Flickr_8k.trainImages.txt').read_text().splitlines()
    test_imgs_path = (path / 'Flickr_8k.testImages.txt').read_text().splitlines()
    
    # Create training and testing datasets
    train_caps = [
        (str(path / 'Flicker8k_Dataset' / img_path), cap_dict[img_path]) 
        for img_path in train_imgs_path
    ]
    test_caps = [
        (str(path / 'Flicker8k_Dataset' / img_path), cap_dict[img_path]) 
        for img_path in test_imgs_path
    ]
    
    # Convert to TensorFlow datasets
    train_raw = tf.data.experimental.from_list(train_caps)
    test_raw = tf.data.experimental.from_list(test_caps)

    return train_raw, test_raw

# %%
get_data()
train_raw, test_raw = get_dataset() # Use path='flickr8k' if on windows

# %%
# Global configurations
image_shape = (224, 224, 3)
vocab_size = 5000
batch_size = 64

# Feature extractor model
feature_extractor = tf.keras.applications.MobileNetV3Small(
    input_shape=image_shape, include_preprocessing=True, include_top=False
)
feature_extractor.trainable = False

# %%
# Helper function to load and preprocess images
def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.io.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, image_shape[:-1])
    return img

# Standardize captions: lowercase, remove punctuation, add [START] and [END]
def standardize(text):
    text = tf.strings.lower(text)
    text = tf.strings.regex_replace(text, f'[{re.escape(string.punctuation)}]', '')
    text = tf.strings.join(['[START]', text, '[END]'], separator=' ')
    return text

# Create TextVectorization layer
vectorizer = tf.keras.layers.TextVectorization(max_tokens = vocab_size,
                                               standardize = standardize,
                                               ragged = True)

vectorizer.adapt(train_raw.map(lambda img_path, cap: cap).unbatch().batch(1024))

# Create mappings between text tokens and IDs
text_to_id_vectorizer = tf.keras.layers.StringLookup(vocabulary = vectorizer.get_vocabulary(), mask_token = '')
id_to_text_vectorizer = tf.keras.layers.StringLookup(vocabulary = vectorizer.get_vocabulary(), mask_token = '', invert = True)

def id_to_text(token_ids, reserved_tokens = ['', '[UNK]', '[START]', '[END]']):
    words = id_to_text_vectorizer(token_ids)
    bad_tokens = [re.escape(tok) for tok in reserved_tokens if tok != '[UNK]']
    bad_tokens_re = '|'.join(bad_tokens)
    bad_mask = tf.strings.regex_full_match(words, bad_tokens_re)
    words = tf.ragged.boolean_mask(words, ~bad_mask)

    return tf.strings.reduce_join(words, axis = -1, separator = ' ')

def serialize_data(images, captions):
    captions_shape = einops.parse_shape(captions, 'b c')
    captions = einops.rearrange(captions, 'b c -> (b c)')
    images = einops.repeat(images, 'b ...  -> (b c) ...', c = captions_shape['c'])
    return images, captions

# Serialize data: duplicate image features for each caption
def serialize_data(images, captions):
    captions_shape = einops.parse_shape(captions, 'b c')
    captions = einops.rearrange(captions, 'b c -> (b c)')
    images = einops.repeat(images, 'b ... -> (b c) ...', c=captions_shape['c'])
    return images, captions

# Prepare batches: tokenize captions into input-output pairs
def prepare_batch(img, cap):
    cap_tokenized = vectorizer(cap)
    cap_tokenized_in = cap_tokenized[:, :-1]
    cap_tokenized_out = cap_tokenized[:, 1:]
    return (img, cap_tokenized_in.to_tensor()), cap_tokenized_out.to_tensor()

# Save preprocessed dataset to disk
def save_dataset(raw_ds, file_path, image_feature_extractor, vectorizer, shards=20, batch_size=64):
    raw_ds = (
        raw_ds.map(lambda img_path, cap: (load_img(img_path), cap), tf.data.AUTOTUNE)
        .batch(batch_size)
    )

    def gen():
        for (img, cap) in tqdm(raw_ds):
            img_features = image_feature_extractor(img)
            img_features, cap = serialize_data(img_features, cap)
            yield img_features, cap

    ds = tf.data.Dataset.from_generator(
        gen,
        output_signature=(
            tf.TensorSpec(shape=image_feature_extractor.output_shape),
            tf.TensorSpec(shape=(None,), dtype=tf.string),
        ),
    )

    ds = (
        ds.map(prepare_batch, tf.data.AUTOTUNE)
        .unbatch()
        .shuffle(1000)
    )

    def shard_func(i, data):
        return i % shards

    ds.enumerate().save(file_path, shard_func=shard_func)

def load_dataset(file_path, batch_size = 64, cycle_length = 2):
    def reader_func(ds):
        ds = ds.shuffle(1000)
        return ds.interleave(lambda x: x, cycle_length = cycle_length)

    def drop_index(i, x):
        return x

    ds = tf.data.Dataset.load(file_path, reader_func = reader_func)

    ds = (ds
          .map(drop_index)
          .shuffle(1000)
          .padded_batch(batch_size)
          .prefetch(tf.data.AUTOTUNE))
    return ds

# %%
# %%time
# save_dataset(train_raw, 'train_cache', feature_extractor, vectorizer)
# save_dataset(test_raw, 'test_cache', feature_extrctor, vectorizer)

train_ds = load_dataset('train_cache', batch_size)
test_ds = load_dataset('test_cache', batch_size)
# Out:
# CPU times: user 67.6 ms, sys: 6.9 ms, total: 74.5 ms
# Wall time: 135 ms

# %%
def positional_encoding(length, depth):
    pos = tf.cast(tf.range(length)[:, tf.newaxis], tf.float32)
    dep = tf.cast(tf.range(depth)[tf.newaxis, :], tf.float32)
    dep = ((dep // 2)*2)/tf.cast(depth, tf.float32)

    angle_rates = 1 / (10000**dep)
    angle_rads = pos*angle_rates

    out = tf.Variable(tf.zeros((length, depth)))
    out[:, 0::2].assign(tf.math.sin(angle_rads[:, 0::2]))
    out[:, 1::2].assign(tf.math.cos(angle_rads[:, 1::2]))

    return out[tf.newaxis, ...]

# %%
class PositionalEmbedding(tf.keras.layers.Layer):
    def __init__(self, vocab_size, d_model):
        super().__init__()
        self.d_model = d_model
        self.embedding = tf.keras.layers.Embedding(vocab_size, d_model, mask_zero = True)
        self.pos_enc = positional_encoding(length = 2048, depth = d_model)

    def compute_mask(self, *args, **kwargs):
        return self.embedding.compute_mask(*args, **kwargs)

    def call(self, x):
        length = tf.shape(x)[1]
        x_emb = self.embedding(x)
        x_pos_enc = self.pos_enc[:, :length, :]

        x_emb *= tf.cast(self.d_model, tf.float32)
        x_emb += x_pos_enc

        return x_emb

class BaseAttention(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super().__init__()
        self.mha = tf.keras.layers.MultiHeadAttention(**kwargs)
        self.add = tf.keras.layers.Add()
        self.layernorm = tf.keras.layers.LayerNormalization()

class CausalAttention(BaseAttention):
    def call(self, x):
        attn_output = self.mha(query = x,
                               key = x,
                               value = x,
                               use_causal_mask = True)

        x = self.add([x, attn_output])
        x = self.layernorm(x)
        return x

class CrossAttention(BaseAttention):
    def call(self, context, x):
        attn_out, attn_scores = self.mha(query = x,
                                         key = context,
                                         value = context,
                                         return_attention_scores = True)

        self.last_attention_scores = attn_scores

        x = self.add([x, attn_out])
        x = self.layernorm(x)
        return x

class FeedForward(tf.keras.layers.Layer):
    def __init__(self, d_model, dff, dropout_rate = 0.1):
        super().__init__()
        self.seq = tf.keras.Sequential([
            tf.keras.layers.Dense(dff, activation = 'relu'),
            tf.keras.layers.Dense(d_model),
            tf.keras.layers.Dropout(rate = dropout_rate)
        ])

        self.add = tf.keras.layers.Add()
        self.layernorm = tf.keras.layers.LayerNormalization()

    def call(self, x):
        x = self.add([x, self.seq(x)])
        x = self.layernorm(x)
        return x

class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, dff, num_heads, dropout_rate = 0.1):
        super().__init__()
        self.causal_attention = CausalAttention(num_heads = num_heads,
                                                key_dim = d_model,
                                                dropout = dropout_rate)
        self.cross_attention = CrossAttention(num_heads = num_heads,
                                              key_dim = d_model,
                                              dropout = dropout_rate)
        self.ffn = FeedForward(d_model = d_model,
                               dff = dff,
                               dropout_rate = dropout_rate)
        self.last_attention_scores = None

    def call(self, context, x):
        x = self.causal_attention(x)
        x = self.cross_attention(context = context, x = x)
        x = self.ffn(x)
        self.last_attention_scores = self.cross_attention.last_attention_scores

        return x

class OutputLayer(tf.keras.layers.Layer):
    def __init__(self, vocab, bad_tokens = ('', '[UNK]', '[START]')):
        super().__init__()
        self.vocab = vocab
        self.bad_tokens = bad_tokens
        self.bias = 0
        self.dense_layer = tf.keras.layers.Dense(len(vocab), activation = tf.nn.log_softmax)

    def adapt(self, cap_ds):
        word_idx = {word : idx for idx, word in enumerate(self.vocab)}
        counts = collections.Counter()
        for tokens in cap_ds:
            counts.update(tokens.numpy().flatten())

        counts_arr = np.zeros((len(self.vocab), ))
        for token_id, cnt in counts.items():
            counts_arr[token_id] = cnt

        bad_indices = np.array([word_idx[word] for word in self.bad_tokens])
        counts_arr[bad_indices] = 0

        counts_prob = counts_arr / counts_arr.sum()
        counts_prob[counts_arr == 0] = 1
        log_p = np.log(counts_prob)

        entropy = (-counts_prob*log_p).sum()

        print(f'uniform_entropy : {np.log(len(self.vocab))}')
        print(f'curr_entropy : {entropy}')
        log_p[counts_arr == 0] = -1e9

        self.bias = log_p[tf.newaxis, tf.newaxis, :]

    def call(self, x):
        return self.dense_layer(x) + self.bias

class Decoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, num_heads, d_model, dff, dropout_rate = 0.1):
        super().__init__()
        self.num_layers = num_layers

        self.positional_embedding = PositionalEmbedding(vocab_size, d_model)
        self.decoder_layers = [DecoderLayer(d_model, dff, num_heads, dropout_rate) for _ in range(num_layers)]
        self.last_attention_scores = None

    def call(self, context, x):
        x = self.positional_embedding(x)
        for i in range(self.num_layers):
            x = self.decoder_layers[i](context = context, x = x)

        self.last_attention_scores = self.decoder_layers[-1].last_attention_scores
        return x

class Captioner(tf.keras.Model):
    @classmethod
    def add_method(cls, fun):
        setattr(cls, fun.__name__, fun)
        return fun

    def __init__(self, vectorizer, feature_extractor, output_layer, num_layers, num_heads, d_model, dff, pred_max_len =  50, dropout_rate = 0.1):
        super().__init__()
        self.feature_extractor = feature_extractor
        self.vectorizer = vectorizer
        self.output_layer = output_layer
        self.decoder = Decoder(num_layers, num_heads, d_model, dff, dropout_rate)
        self.max_len = pred_max_len
        self.vocab = self.vectorizer.get_vocabulary()

    def call(self, inputs):
        context, cap = inputs
        if context.shape[-1] == 3:
            context = self.feature_extractor(context)
        context = einops.rearrange(context, 'b h w c -> b (h w) c')

        if cap.dtype == tf.string:
            cap = self.vectorizer([cap])


        x = self.decoder(context = context, x = cap)
        x = self.output_layer(x)
        return x

# %%
d_model = 128
dff = 128
dropout_rate = 0.4
num_layers = 2
num_heads = 2

vocab = vectorizer.get_vocabulary()
output_layer = OutputLayer(vocab)
output_layer.adapt(train_ds.map(lambda img_feature, cap: cap))
# Out:
# uniform_entropy : 8.517193191416238
# curr_entropy : 5.292547935444457

# %%
# %%time
captioner_model = Captioner(vectorizer = vectorizer,
                            feature_extractor = feature_extractor,
                            output_layer = output_layer,
                            num_layers = num_layers,
                            num_heads = num_heads,
                            d_model = d_model,
                            dff = dff,
                            dropout_rate = dropout_rate)
# Out:
# CPU times: user 29.8 ms, sys: 11.1 ms, total: 40.9 ms
# Wall time: 39.3 ms

# %%
@Captioner.add_method
def generate_text(self, img, temperature = 0.5):
    if img.shape[-1] == 3:
        img = self.feature_extractor(img)
    start_token = text_to_id_vectorizer([['[START]']])

    start_idx = self.vocab.index('[START]')
    end_idx = self.vocab.index('[END]')

    for i in range(self.max_len):
        preds = self((img, start_token))
        preds = preds[:, -1, :]
        if temperature == 0.0:
            pred_idx = tf.argmax(preds, axis = -1)[:, tf.newaxis]
        else:
            preds /= temperature
            pred_idx = tf.random.categorical(preds, num_samples = 1)

        start_token = tf.concat([start_token, pred_idx], axis = -1)

        if pred_idx[0][0] == end_idx:
            break

    return id_to_text(start_token).numpy()[0].decode('utf-8')

def brevity_penalty(can, ref):
    can_tokens = nltk.word_tokenize(can)
    ref_tokens = nltk.word_tokenize(ref)
    if len(can_tokens) == 0:
        return 0.0
    return min(1, np.exp(1 - (len(ref_tokens) / len(can_tokens))))

def precision(can, ref, n):
    can_n = collections.Counter(ngrams(nltk.word_tokenize(can), n))
    ref_n = collections.Counter(ngrams(nltk.word_tokenize(ref), n))
    total = sum(can_n.values())

    if total == 0:
        return 0

    for n_g in can_n:
        if n_g in ref_n:
            can_n[n_g] = min(can_n[n_g], ref_n[n_g])
        else:
            can_n[n_g] = 0
    return sum(can_n.values()) / total

def bleu_score(can , ref, n_gram_range = 2):
    precisions = []
    b_p = brevity_penalty(can, ref)
    for n in range(1, n_gram_range + 1):
        precisions.append(precision(can, ref, n))
    precisions = np.array(precisions)

    if 0 in precisions:
        # As log of 0 will be -inf and exp of that will be back to 0 with warning.
        return 0.0
    return b_p * np.exp(np.log(precisions).mean())

def recall(can, ref, n):
    can_n = collections.Counter(ngrams(nltk.word_tokenize(can), n))
    ref_n = collections.Counter(ngrams(nltk.word_tokenize(ref), n))
    total = sum(ref_n.values())

    if total == 0:
        return 0

    for n_g in ref_n:
        if n_g in can_n:
            ref_n[n_g] = min(can_n[n_g], ref_n[n_g])
        else:
            ref_n[n_g] = 0
    return sum(ref_n.values()) / total

def rouge_score(can , ref, n_gram_range = 2):
    recalls = []
    b_p = brevity_penalty(can, ref)
    for n in range(1, n_gram_range + 1):
        recalls.append(recall(can, ref, n))
    recalls = np.array(recalls)

    if 0 in recalls:
        # As log of 0 will be -inf and exp of that will be back to 0 with warning.
        return 0.0
    return b_p * np.exp(np.log(recalls).mean())

@Captioner.add_method
def f_score(self, can, refs, n_gram_range = 1):
    b_scores = [bleu_score(can, ref, n_gram_range) for ref in refs]
    r_scores = [rouge_score(can, ref, n_gram_range)  for ref in refs]
    f_vals = []
    for b_score, r_score in zip(b_scores, r_scores):
        if b_score + r_score == 0:
            return 0
        f_vals.append((2*b_score*r_score) / (b_score + r_score))

    return max(f_vals)

def masked_loss(labels, preds):
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True, reduction = 'none')
    loss = tf.cast(loss_fn(labels, preds), tf.float32)
    mask = ((labels != 0) & (loss < 1e8))
    mask = tf.cast(mask, tf.float32)
    loss *= mask
    return tf.math.reduce_sum(loss) / tf.math.reduce_sum(mask)

def masked_accuracy(labels, preds):
    preds = tf.cast(tf.argmax(preds, axis = -1), tf.float32)
    labels = tf.cast(labels, tf.float32)
    mask = tf.cast(labels != 0, tf.float32)
    acc = tf.cast(preds == labels, tf.float32)
    acc *= mask
    return tf.math.reduce_sum(acc) / tf.math.reduce_sum(mask)

# %%
for img_path, caps in train_raw.take(1):
    break

img = load_img(img_path)
caps = [cap.numpy().decode('utf-8') for cap in caps]

# %%
class GenerateText(tf.keras.callbacks.Callback):
    def __init__(self, img = img):
        self.image = img[tf.newaxis, ...]
        self.caps = caps

    def on_epoch_end(self, epochs = None, logs = None):
        print('\n')
        for temp in (0, 0.5, 1):
            gen_text = self.model.generate_text(self.image)
            f_val = self.model.f_score(gen_text, self.caps, n_gram_range = 1)
            print(f'Generated_text: {gen_text}, \t f_score: {f_val}')

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0001)
captioner_model.compile(loss = masked_loss, optimizer = optimizer, metrics = [masked_accuracy])
callbacks = [GenerateText(), tf.keras.callbacks.EarlyStopping(patience = 6, restore_best_weights = True)]

# %%
hist = captioner_model.fit(
    train_ds.repeat(),
    steps_per_epoch = 100,
    validation_data = test_ds.repeat(),
    validation_steps = 20,
    epochs = 200,
    callbacks = callbacks
)
# Out:
# Epoch 1/200
# /Users/saurabh/Documents/projects/caption-lens/venv/lib/python3.11/site-packages/keras/src/layers/layer.py:932: UserWarning: Layer 'causal_attention' (of type CausalAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# /Users/saurabh/Documents/projects/caption-lens/venv/lib/python3.11/site-packages/keras/src/layers/layer.py:932: UserWarning: Layer 'sequential' (of type Sequential) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# /Users/saurabh/Documents/projects/caption-lens/venv/lib/python3.11/site-packages/keras/src/layers/layer.py:932: UserWarning: Layer 'feed_forward' (of type FeedForward) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# /Users/saurabh/Documents/projects/caption-lens/venv/lib/python3.11/site-packages/keras/src/layers/layer.py:932: UserWarning: Layer 'causal_attention_1' (of type CausalAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# /Users/saurabh/Documents/projects/caption-lens/venv/lib/python3.11/site-packages/keras/src/layers/layer.py:932: UserWarning: Layer 'sequential_1' (of type Sequential) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# /Users/saurabh/Documents/projects/caption-lens/venv/lib/python3.11/site-packages/keras/src/layers/layer.py:932: UserWarning: Layer 'feed_forward_1' (of type FeedForward) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# /Users/saurabh/Documents/projects/caption-lens/venv/lib/python3.11/site-packages/keras/src/layers/layer.py:932: UserWarning: Layer 'output_layer' (of type OutputLayer) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# /Users/saurabh/Documents/projects/caption-lens/venv/lib/python3.11/site-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'captioner', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Generated_text: a dog dog in a, 	 f_score: 0
# 37m 0s 172ms/step - loss: 5.1429 - masked_accuracy: 0.1649
# /Users/saurabh/Documents/projects/caption-lens/venv/lib/python3.11/site-packages/keras/src/ops/nn.py:827: UserWarning: You are using a softmax over axis 3 of a tensor of shape (1, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# Generated_text: a dog two in a and on a dog, 	 f_score: 0
# Generated_text: a in a dog, 	 f_score: 0
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 194ms/step - loss: 5.1415 - masked_accuracy: 0.1652 - val_loss: 4.7017 - val_masked_accuracy: 0.2302
# Epoch 2/200
#
#
# Generated_text: a dog is dog in the, 	 f_score: 0.26045591535095813
# Generated_text: a dog with a dog is dog and white dog, 	 f_score: 0
# Generated_text: a dog a small dog is is a black dog, 	 f_score: 0
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 19s 186ms/step - loss: 4.6724 - masked_accuracy: 0.2454 - val_loss: 4.4258 - val_masked_accuracy: 0.2648
# Epoch 3/200
#
#
# Generated_text: a dog and a dog is a black dog on the a dog, 	 f_score: 0.46153846153846156
# Generated_text: a dog in a dog in a dog, 	 f_score: 0
# Generated_text: a dog running in a white dog is on a field, 	 f_score: 0
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 199ms/step - loss: 4.4387 - masked_accuracy: 0.2713 - val_loss: 4.2406 - val_masked_accuracy: 0.2825
# Epoch 4/200
#
#
# Generated_text: a dog is jumping in the snow, 	 f_score: 0.34675115990007266
# Generated_text: two dogs two the field, 	 f_score: 0
# Generated_text: a dog is running through the water, 	 f_score: 0.2857142857142857
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 204ms/step - loss: 4.2552 - masked_accuracy: 0.2901 - val_loss: 4.0363 - val_masked_accuracy: 0.3104
# Epoch 5/200
#
#
# Generated_text: a dog is in a black dog is and another dog, 	 f_score: 0
# Generated_text: a dog is running through the the snow, 	 f_score: 0.39999999999999997
# Generated_text: a dog is dog in a obstacle, 	 f_score: 0
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 203ms/step - loss: 4.1134 - masked_accuracy: 0.3115 - val_loss: 3.9952 - val_masked_accuracy: 0.3211
# Epoch 6/200
#
#
# Generated_text: the black dog is running through the snow, 	 f_score: 0.39999999999999997
# Generated_text: a white dog runs through the snow, 	 f_score: 0.42857142857142855
# Generated_text: a dog is running on the grass, 	 f_score: 0.212186422838475
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 201ms/step - loss: 3.9362 - masked_accuracy: 0.3290 - val_loss: 3.8560 - val_masked_accuracy: 0.3295
# Epoch 7/200
#
#
# Generated_text: a black and black dog is running through the snow, 	 f_score: 0.45093282998017614
# Generated_text: two dogs are playing in a field, 	 f_score: 0
# Generated_text: two dogs are playing in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 196ms/step - loss: 3.8910 - masked_accuracy: 0.3348 - val_loss: 3.7754 - val_masked_accuracy: 0.3366
# Epoch 8/200
#
#
# Generated_text: a dog is looking on a snow, 	 f_score: 0
# Generated_text: a dog is running in the snow, 	 f_score: 0.34675115990007266
# Generated_text: a dog is wearing a black dog with a ball in the snow, 	 f_score: 0.6153846153846154
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 198ms/step - loss: 3.7865 - masked_accuracy: 0.3432 - val_loss: 3.6954 - val_masked_accuracy: 0.3414
# Epoch 9/200
#
#
# Generated_text: a dog is running in a snow, 	 f_score: 0
# Generated_text: four dogs are standing on the snow, 	 f_score: 0.34675115990007266
# Generated_text: a brown dog is running through the the snow, 	 f_score: 0.5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 197ms/step - loss: 3.7540 - masked_accuracy: 0.3410 - val_loss: 3.6661 - val_masked_accuracy: 0.3422
# Epoch 10/200
#
#
# Generated_text: a black dog is running in the snow, 	 f_score: 0.40781823125256406
# Generated_text: a black dog in the snow, 	 f_score: 0.30708484738876685
# Generated_text: a black dog is running on the snow while a blue, 	 f_score: 0.4863558688771886
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 197ms/step - loss: 3.6604 - masked_accuracy: 0.3539 - val_loss: 3.6283 - val_masked_accuracy: 0.3462
# Epoch 11/200
#
#
# Generated_text: a dog is running in the snow, 	 f_score: 0.34675115990007266
# Generated_text: a dog is running through the snow, 	 f_score: 0.42857142857142855
# Generated_text: a dog is playing in a ball, 	 f_score: 0
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 197ms/step - loss: 3.5767 - masked_accuracy: 0.3587 - val_loss: 3.5935 - val_masked_accuracy: 0.3487
# Epoch 12/200
#
#
# Generated_text: a dog is running through the snow with a snow, 	 f_score: 0.38651385426872237
# Generated_text: two dogs are running down a snow, 	 f_score: 0.2311674399333818
# Generated_text: a dog is jumping in the snow, 	 f_score: 0.34675115990007266
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 200ms/step - loss: 3.5269 - masked_accuracy: 0.3656 - val_loss: 3.5518 - val_masked_accuracy: 0.3478
# Epoch 13/200
#
#
# Generated_text: a black dog is running in the snow, 	 f_score: 0.40781823125256406
# Generated_text: a black dog running in the snow, 	 f_score: 0.34675115990007266
# Generated_text: two dogs run in the snow, 	 f_score: 0.40944646318502237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 199ms/step - loss: 3.4647 - masked_accuracy: 0.3710 - val_loss: 3.5090 - val_masked_accuracy: 0.3552
# Epoch 14/200
#
#
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# Generated_text: two dogs run through the snow, 	 f_score: 0.30708484738876685
# Generated_text: a dog does a frisbee in the snow, 	 f_score: 0.375
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 229ms/step - loss: 3.4375 - masked_accuracy: 0.3740 - val_loss: 3.4513 - val_masked_accuracy: 0.3604
# Epoch 15/200
#
#
# Generated_text: two dogs are running through the snow, 	 f_score: 0.34675115990007266
# Generated_text: two dogs are running through the snow, 	 f_score: 0.34675115990007266
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 229ms/step - loss: 3.3985 - masked_accuracy: 0.3752 - val_loss: 3.3901 - val_masked_accuracy: 0.3697
# Epoch 16/200
#
#
# Generated_text: two dogs are playing in the snow, 	 f_score: 0.4623348798667636
# Generated_text: two dogs are playing on the snow, 	 f_score: 0.34675115990007266
# Generated_text: dogs are running through snow, 	 f_score: 0.2234400153452131
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 256ms/step - loss: 3.3284 - masked_accuracy: 0.3836 - val_loss: 3.3727 - val_masked_accuracy: 0.3653
# Epoch 17/200
#
#
# Generated_text: two dogs are running through the snow, 	 f_score: 0.34675115990007266
# Generated_text: two dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: a black dog is running in the snow, 	 f_score: 0.40781823125256406
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 244ms/step - loss: 3.3195 - masked_accuracy: 0.3828 - val_loss: 3.3269 - val_masked_accuracy: 0.3697
# Epoch 18/200
#
#
# Generated_text: two black dogs are running through the snow, 	 f_score: 0.375
# Generated_text: two dogs are running through the snow, 	 f_score: 0.34675115990007266
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 244ms/step - loss: 3.2741 - masked_accuracy: 0.3848 - val_loss: 3.3469 - val_masked_accuracy: 0.3688
# Epoch 19/200
#
#
# Generated_text: a black and white dog running through the snow, 	 f_score: 0.4080238835463348
# Generated_text: two dogs running through the snow, 	 f_score: 0.30708484738876685
# Generated_text: two dogs running across the snow, 	 f_score: 0.30708484738876685
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - loss: 3.2541 - masked_accuracy: 0.3866 - val_loss: 3.2810 - val_masked_accuracy: 0.3713
# Epoch 20/200
#
#
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# Generated_text: two dogs are running through the snow, 	 f_score: 0.34675115990007266
# Generated_text: people are running through the snow, 	 f_score: 0.26045591535095813
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 235ms/step - loss: 3.1627 - masked_accuracy: 0.4002 - val_loss: 3.2462 - val_masked_accuracy: 0.3720
# Epoch 21/200
#
#
# Generated_text: two dogs running through a snow, 	 f_score: 0.26045591535095813
# Generated_text: two dogs are playing in the snow, 	 f_score: 0.4623348798667636
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 239ms/step - loss: 3.1554 - masked_accuracy: 0.4012 - val_loss: 3.2246 - val_masked_accuracy: 0.3751
# Epoch 22/200
#
#
# Generated_text: two dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: two dogs run across the snow, 	 f_score: 0.30708484738876685
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 239ms/step - loss: 3.1490 - masked_accuracy: 0.3984 - val_loss: 3.2076 - val_masked_accuracy: 0.3831
# Epoch 23/200
#
#
# Generated_text: two dogs running through the snow, 	 f_score: 0.30708484738876685
# Generated_text: two dogs run through the snow, 	 f_score: 0.30708484738876685
# Generated_text: dog running through snow, 	 f_score: 0
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - loss: 3.1429 - masked_accuracy: 0.3987 - val_loss: 3.2206 - val_masked_accuracy: 0.3797
# Epoch 24/200
#
#
# Generated_text: a black dog is running through the snow, 	 f_score: 0.39999999999999997
# Generated_text: a black dog is running through the snow, 	 f_score: 0.39999999999999997
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 242ms/step - loss: 3.1179 - masked_accuracy: 0.4020 - val_loss: 3.1663 - val_masked_accuracy: 0.3827
# Epoch 25/200
#
#
# Generated_text: two dogs are running on the beach, 	 f_score: 0
# Generated_text: two dogs play in the snow, 	 f_score: 0.511808078981278
# Generated_text: two dogs are running through the snow, 	 f_score: 0.34675115990007266
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 243ms/step - loss: 2.9946 - masked_accuracy: 0.4162 - val_loss: 3.1690 - val_masked_accuracy: 0.3757
# Epoch 26/200
#
#
# Generated_text: black dog running in the snow, 	 f_score: 0.30708484738876685
# Generated_text: two dogs run in the snow, 	 f_score: 0.40944646318502237
# Generated_text: black dog walking through the snow, 	 f_score: 0.3906838730264372
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 238ms/step - loss: 3.0156 - masked_accuracy: 0.4129 - val_loss: 3.1856 - val_masked_accuracy: 0.3810
# Epoch 27/200
#
#
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# Generated_text: a dog running through the snow, 	 f_score: 0.3906838730264372
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 240ms/step - loss: 3.0025 - masked_accuracy: 0.4146 - val_loss: 3.1380 - val_masked_accuracy: 0.3815
# Epoch 28/200
#
#
# Generated_text: two dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: two dogs are running through the snow, 	 f_score: 0.34675115990007266
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 245ms/step - loss: 2.9678 - masked_accuracy: 0.4183 - val_loss: 3.1768 - val_masked_accuracy: 0.3744
# Epoch 29/200
#
#
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# Generated_text: two dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: a black dog runs through the snow, 	 f_score: 0.42857142857142855
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 246ms/step - loss: 2.9485 - masked_accuracy: 0.4206 - val_loss: 3.1115 - val_masked_accuracy: 0.3875
# Epoch 30/200
#
#
# Generated_text: dog running along the snowy hill, 	 f_score: 0.13022795767547907
# Generated_text: three dogs are running through a field, 	 f_score: 0.25098583200344854
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 250ms/step - loss: 2.9004 - masked_accuracy: 0.4232 - val_loss: 3.1578 - val_masked_accuracy: 0.3803
# Epoch 31/200
#
#
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# Generated_text: three dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: two dogs are running through the snow, 	 f_score: 0.34675115990007266
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 245ms/step - loss: 2.8837 - masked_accuracy: 0.4267 - val_loss: 3.1096 - val_masked_accuracy: 0.3858
# Epoch 32/200
#
#
# Generated_text: two dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: two dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 242ms/step - loss: 2.8758 - masked_accuracy: 0.4295 - val_loss: 3.1004 - val_masked_accuracy: 0.3875
# Epoch 33/200
#
#
# Generated_text: three dogs run through the snow, 	 f_score: 0.30708484738876685
# Generated_text: two dogs are playing in the snow, 	 f_score: 0.4623348798667636
# Generated_text: two dogs run through the snow, 	 f_score: 0.30708484738876685
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 257ms/step - loss: 2.8667 - masked_accuracy: 0.4247 - val_loss: 3.0850 - val_masked_accuracy: 0.3863
# Epoch 34/200
#
#
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# Generated_text: three dogs run through the snow, 	 f_score: 0.30708484738876685
# Generated_text: two dogs running in the snow, 	 f_score: 0.40944646318502237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 247ms/step - loss: 2.8006 - masked_accuracy: 0.4354 - val_loss: 3.0646 - val_masked_accuracy: 0.3826
# Epoch 35/200
#
#
# Generated_text: dogs are running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: dogs are running through the snow, 	 f_score: 0.30708484738876685
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 258ms/step - loss: 2.7934 - masked_accuracy: 0.4361 - val_loss: 3.0513 - val_masked_accuracy: 0.3845
# Epoch 36/200
#
#
# Generated_text: two dogs running through the snow, 	 f_score: 0.30708484738876685
# Generated_text: two dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: three dogs running through the snow, 	 f_score: 0.30708484738876685
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 254ms/step - loss: 2.8049 - masked_accuracy: 0.4341 - val_loss: 3.0725 - val_masked_accuracy: 0.3858
# Epoch 37/200
#
#
# Generated_text: dogs one black dog runs through the snow, 	 f_score: 0.39999999999999997
# Generated_text: dogs running in the snow, 	 f_score: 0.3377302375963239
# Generated_text: two black dogs running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 253ms/step - loss: 2.7881 - masked_accuracy: 0.4378 - val_loss: 3.0034 - val_masked_accuracy: 0.3935
# Epoch 38/200
#
#
# Generated_text: three dogs are running through the snow, 	 f_score: 0.34675115990007266
# Generated_text: three dogs running through the snow, 	 f_score: 0.30708484738876685
# Generated_text: two dogs running through the snow, 	 f_score: 0.30708484738876685
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 256ms/step - loss: 2.7472 - masked_accuracy: 0.4412 - val_loss: 3.0313 - val_masked_accuracy: 0.3899
# Epoch 39/200
#
#
# Generated_text: three dogs play in the snow, 	 f_score: 0.511808078981278
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# Generated_text: three dogs run and one as one is running towards the snow, 	 f_score: 0.3
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 260ms/step - loss: 2.7073 - masked_accuracy: 0.4460 - val_loss: 3.0460 - val_masked_accuracy: 0.3853
# Epoch 40/200
#
#
# Generated_text: three dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: three dogs playing in the snow, 	 f_score: 0.40944646318502237
# Generated_text: two dogs run through the snow, 	 f_score: 0.30708484738876685
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 260ms/step - loss: 2.6713 - masked_accuracy: 0.4495 - val_loss: 2.9923 - val_masked_accuracy: 0.3953
# Epoch 41/200
#
#
# Generated_text: a black dog runs in the snow, 	 f_score: 0.34675115990007266
# Generated_text: three dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: two dogs are running through the snow, 	 f_score: 0.34675115990007266
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 262ms/step - loss: 2.6984 - masked_accuracy: 0.4484 - val_loss: 3.0084 - val_masked_accuracy: 0.3916
# Epoch 42/200
#
#
# Generated_text: two dogs run in the snow, 	 f_score: 0.40944646318502237
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# Generated_text: two black dogs running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 252ms/step - loss: 2.6731 - masked_accuracy: 0.4499 - val_loss: 3.0082 - val_masked_accuracy: 0.3874
# Epoch 43/200
#
#
# Generated_text: two dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: two dogs running through the snow, 	 f_score: 0.30708484738876685
# Generated_text: three dogs running in the snow, 	 f_score: 0.40944646318502237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 244ms/step - loss: 2.6310 - masked_accuracy: 0.4531 - val_loss: 2.9973 - val_masked_accuracy: 0.3907
# Epoch 44/200
#
#
# Generated_text: two black dogs are running through a field, 	 f_score: 0.2893849594909357
# Generated_text: a dog runs through the snow, 	 f_score: 0.3906838730264372
# Generated_text: dogs running in the snow, 	 f_score: 0.3377302375963239
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 249ms/step - loss: 2.6139 - masked_accuracy: 0.4573 - val_loss: 3.0147 - val_masked_accuracy: 0.3914
# Epoch 45/200
#
#
# Generated_text: three dogs are playing in the snow, 	 f_score: 0.4623348798667636
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 257ms/step - loss: 2.6100 - masked_accuracy: 0.4572 - val_loss: 2.9726 - val_masked_accuracy: 0.3930
# Epoch 46/200
#
#
# Generated_text: two dogs are running through the snow, 	 f_score: 0.34675115990007266
# Generated_text: two dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: two dogs are running through the snow, 	 f_score: 0.34675115990007266
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 249ms/step - loss: 2.6150 - masked_accuracy: 0.4564 - val_loss: 3.0084 - val_masked_accuracy: 0.3924
# Epoch 47/200
#
#
# Generated_text: three dogs running through the snow, 	 f_score: 0.30708484738876685
# Generated_text: two dogs are running through the snow, 	 f_score: 0.34675115990007266
# Generated_text: two dogs running in the snow, 	 f_score: 0.40944646318502237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 251ms/step - loss: 2.6084 - masked_accuracy: 0.4585 - val_loss: 3.0202 - val_masked_accuracy: 0.3902
# Epoch 48/200
#
#
# Generated_text: a white dog running in the snow, 	 f_score: 0.34675115990007266
# Generated_text: three dogs are running in the snow, 	 f_score: 0.4623348798667636
# Generated_text: three dogs running through the snow, 	 f_score: 0.30708484738876685
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 256ms/step - loss: 2.5372 - masked_accuracy: 0.4653 - val_loss: 3.0179 - val_masked_accuracy: 0.3920
# Epoch 49/200
#
#
# Generated_text: dogs running in the snow, 	 f_score: 0.3377302375963239
# Generated_text: three dogs run through the snow, 	 f_score: 0.30708484738876685
# Generated_text: three dogs running in the snow, 	 f_score: 0.40944646318502237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 239ms/step - loss: 2.5050 - masked_accuracy: 0.4709 - val_loss: 2.9409 - val_masked_accuracy: 0.3976
# Epoch 50/200
#
#
# Generated_text: three dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: three dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: a black dog is running through the snow, 	 f_score: 0.39999999999999997
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 235ms/step - loss: 2.5458 - masked_accuracy: 0.4651 - val_loss: 3.0031 - val_masked_accuracy: 0.3900
# Epoch 51/200
#
#
# Generated_text: two dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# Generated_text: two dogs are running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 235ms/step - loss: 2.5220 - masked_accuracy: 0.4680 - val_loss: 2.9398 - val_masked_accuracy: 0.3997
# Epoch 52/200
#
#
# Generated_text: a dog runs in the snow, 	 f_score: 0.30708484738876685
# Generated_text: three black dogs are running in the snow, 	 f_score: 0.5
# Generated_text: two dogs running in the snow, 	 f_score: 0.40944646318502237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 256ms/step - loss: 2.5024 - masked_accuracy: 0.4690 - val_loss: 2.9602 - val_masked_accuracy: 0.3949
# Epoch 53/200
#
#
# Generated_text: four dogs are running through a snowy field, 	 f_score: 0.2893849594909357
# Generated_text: three dogs are running in the snow, 	 f_score: 0.4623348798667636
# Generated_text: two dogs play in the snow, 	 f_score: 0.511808078981278
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 252ms/step - loss: 2.4278 - masked_accuracy: 0.4819 - val_loss: 2.9388 - val_masked_accuracy: 0.3966
# Epoch 54/200
#
#
# Generated_text: two dogs play in the snow, 	 f_score: 0.511808078981278
# Generated_text: two dogs run through the snow, 	 f_score: 0.30708484738876685
# Generated_text: a tan dog runs through snow, 	 f_score: 0
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 252ms/step - loss: 2.4595 - masked_accuracy: 0.4756 - val_loss: 2.9856 - val_masked_accuracy: 0.3900
# Epoch 55/200
#
#
# Generated_text: a white dog is running through the snow, 	 f_score: 0.39999999999999997
# Generated_text: three dogs are running through the snow, 	 f_score: 0.34675115990007266
# Generated_text: two dogs play in the snow, 	 f_score: 0.511808078981278
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 249ms/step - loss: 2.4283 - masked_accuracy: 0.4821 - val_loss: 2.9005 - val_masked_accuracy: 0.3996
# Epoch 56/200
#
#
# Generated_text: three dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: three dogs play in the snow, 	 f_score: 0.511808078981278
# Generated_text: a black dog running in the snow, 	 f_score: 0.34675115990007266
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 238ms/step - loss: 2.4778 - masked_accuracy: 0.4742 - val_loss: 2.9835 - val_masked_accuracy: 0.3898
# Epoch 57/200
#
#
# Generated_text: three dogs running and running in the snow, 	 f_score: 0.5
# Generated_text: two dogs running through the snow, 	 f_score: 0.30708484738876685
# Generated_text: two black dogs running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 221ms/step - loss: 2.4426 - masked_accuracy: 0.4781 - val_loss: 2.9973 - val_masked_accuracy: 0.3914
# Epoch 58/200
#
#
# Generated_text: two dogs running through the snow, 	 f_score: 0.30708484738876685
# Generated_text: three dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: three dogs are running in the snow, 	 f_score: 0.4623348798667636
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 253ms/step - loss: 2.3788 - masked_accuracy: 0.4869 - val_loss: 2.9688 - val_masked_accuracy: 0.3943
# Epoch 59/200
#
#
# Generated_text: three dogs are running through the snow, 	 f_score: 0.34675115990007266
# Generated_text: three dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: a black dog runs through the snow, 	 f_score: 0.42857142857142855
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 251ms/step - loss: 2.4025 - masked_accuracy: 0.4859 - val_loss: 2.9513 - val_masked_accuracy: 0.3959
# Epoch 60/200
#
#
# Generated_text: two dogs run through the snow, 	 f_score: 0.30708484738876685
# Generated_text: three dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: two dogs running through snow, 	 f_score: 0.2234400153452131
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 248ms/step - loss: 2.3998 - masked_accuracy: 0.4843 - val_loss: 2.9801 - val_masked_accuracy: 0.3881
# Epoch 61/200
#
#
# Generated_text: three dogs are running in the snow, 	 f_score: 0.4623348798667636
# Generated_text: three dogs running in the snow, 	 f_score: 0.40944646318502237
# Generated_text: three dogs running in the snow, 	 f_score: 0.40944646318502237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 255ms/step - loss: 2.3912 - masked_accuracy: 0.4807 - val_loss: 2.9844 - val_masked_accuracy: 0.3972

# %%
plt.figure(figsize = (10, 4))
plt.subplot(1, 2, 1)
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label = 'val_loss')

plt.subplot(1, 2, 2)
plt.plot(hist.history['masked_accuracy'], label = 'masked_accuracy')
plt.plot(hist.history['val_masked_accuracy'], label = 'val_masked_accuracy')
plt.show()

# %%
@Captioner.add_method
def show_attention(self, img, temperature=0.5):
    """
    Visualizes the attention maps for the generated caption.

    Args:
        img: Input image as a tensor.
        temperature: Sampling temperature for text generation.

    Returns:
        None
    """
    # Generate text using the captioning model
    gen_text = self.generate_text(img=img[tf.newaxis, ...], temperature=temperature)  # Adjusted generate_text call
    cap_gen_tokens = gen_text.split() + ['[END]']  # Add [END] to match token generation
    
    # Get attention scores from the decoder
    attn_scores = self.decoder.last_attention_scores  # Shape: (batch, num_heads, seq_len, h*w)
    attn_maps = einops.reduce(attn_scores, 'b num_heads seq_len (h w) -> seq_len h w', 
                              h=7, w=7, reduction='mean')  # Average across heads
    
    # Ensure lengths align between tokens and attention maps
    len_result = min(len(attn_maps), len(cap_gen_tokens))  # Use the shorter length
    col_len = int(np.ceil(len_result / 2))  # Number of columns for subplot grid
    row_len = 2  # Number of rows for subplot grid

    # Plot the image with attention maps for each token
    plt.figure(figsize=(15, 5))
    for i in range(len_result):
        ax = plt.subplot(row_len, col_len, i + 1)
        img_plot = ax.imshow(img / 255)  # Normalize image for display
        plt.title(cap_gen_tokens[i])  # Add token as the title
        ax.imshow(attn_maps[i], cmap='gray', alpha=0.6, 
                  extent=img_plot.get_extent(), 
                  clim=[0, np.max(attn_maps[i])])  # Overlay attention map
        plt.axis('off')  # Remove axes

    plt.tight_layout()
    plt.show()

# %%
img_path = input("Enter the image path: ")
img = load_img(img_path)
plt.imshow(img/255.0)
plt.show()
print(f'Generated Caption: {captioner_model.generate_text(img[tf.newaxis, ...])}')
# Out:
# Enter the image path:  test.jpg
# Generated Caption: a young girl in a blue shorts is jumping in the air

# %%
captioner_model.show_attention(img)
